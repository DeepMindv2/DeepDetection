# %%
# Necessary Dependencies
import os 
import time
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.image as img 
print('Started')
# Out:
# Started

# %% [markdown]
# ## Multi-Chest Xray Dataset
#
# https://www.kaggle.com/jbeltranleon/datasets
#
# This dataset contains 9 different classes: mass,cardiomegaly, atelectasis, effusion, pneumothorax, no_finding, nodule, and infiltration'

# %%
TRAIN_DIR = '/Users/ryanjoseph/Desktop/Yale/Repositories/Pneumonia/Multi_Chest/Data/train/'
TEST_DIR = '/Users/ryanjoseph/Desktop/Yale/Repositories/Pneumonia/Multi_Chest/Data/test/'
VAL_DIR = '/Users/ryanjoseph/Desktop/Yale/Repositories/Pneumonia/Multi_Chest/Data/val/'

EFFUSION_DIR = '/Users/ryanjoseph/Desktop/Yale/Repositories/Pneumonia/Multi_Chest/Data/train/effusion'

# %%
# There are 9 Disease Classes in Each directory
diseases = ['mass','cardiomegaly', 'atelectasis', 'effusion', 'pneumothorax', 'no_finding', 'nodule', 'infiltration', 'consolidation']

# %%
disease_class = []
Number = []
def class_imbalance(dire):  
    list = os.listdir(dire)
    for i in list:
        if i =='.DS_Store':
            pass
        else:
            #print('Disease Class: ', i)
            disease_class.append(i)
            new = os.listdir(dire + i)
            number_files = len(new)
            Number.append(number_files)
            #print ('NUMBER OF FILES: ', number_files)
        
    df = pd.DataFrame(Number, disease_class)
    
    fig, ax1 = plt.subplots(1,1,figsize=(10,5))

    df.plot(kind="bar", ax=ax1, title=f"Disease Classes")
    print(df)

# %%
class_imbalance(TRAIN_DIR)
# Out:
#                   0
# mass           1368
# cardiomegaly    699
# atelectasis    2697
# effusion       2531
# pneumothorax   1404
# Small             3
# no_finding     6400
# nodule         1731
# infiltration   6109
# consolidation   838

# %%
directory = '/Users/ryanjoseph/Desktop/Yale/Repositories/Pneumonia/Multi_Chest/Data/train/Sample'

flow_from_directory(directory,
                    target_size=(160, 160),
                    color_mode='rgb',
                    classes=None,
                    class_mode='categorical',
                    batch_size=32,
                    shuffle=True,
                    seed=1,
                    save_to_dir=True,
                    save_prefix='',
                    save_format='png',
                    follow_links=False,
                    subset=None,
                    interpolation='nearest')

# %%
# Fast Visualization function
def quick_view(disease_type):
    mass_dir = TRAIN_DIR + disease_type + '/'
    mass_num = os.listdir(mass_dir)
    mass_num_1 = mass_dir + mass_num[1]
    print(f'Disease Class: {disease_type}')
    img2 = img.imread(mass_num_1)
    print('Image Shape: ', img2.shape)
    plt.imshow(img2)
    
    y = fig.add_subplot(3,4,3+1)
    y.imshow(img2,cmap='gray')


disease_type = 'mass'
quick_view(disease_type)
# Out:
# Disease Class: mass
# Image Shape:  (299, 299)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-95ea4dbb6761> in <module>
#      14
#      15 disease_type = 'mass'
# ---> 16 quick_view(disease_type)
#
# <ipython-input-11-95ea4dbb6761> in quick_view(disease_type)
#       9     plt.imshow(img2)
#      10
# ---> 11     y = fig.add_subplot(3,4,3+1)
#      12     y.imshow(img2,cmap='gray')
#      13
#
# NameError: name 'fig' is not defined

# %%
# Fast Visualization function
def quick_view(disease_type):
    mass_dir = TRAIN_DIR + disease_type + '/'
    mass_num = os.listdir(mass_dir)
    mass_num_1 = mass_dir + mass_num[1]
    print(f'Disease Class: {disease_type}')
    img2 = img.imread(mass_num_1)
    print('Image Shape: ', img2.shape)
    plt.imshow(img2)

    
disease_type = 'mass'
quick_view(disease_type)
# Out:
# Disease Class: mass
# Image Shape:  (299, 299)

# %% [markdown]
# ## Mass

# %%
disease_type = 'mass'
quick_view(disease_type)
# Out:
# Disease Class: mass
# Image Shape:  (299, 299)

# %% [markdown]
# ## Cardiomegaly

# %%
disease_type = 'cardiomegaly'
quick_view(disease_type)
# Out:
# Disease Class: cardiomegaly
